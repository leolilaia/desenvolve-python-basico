# %% [markdown]
# # Tupla
#
# ## Aula 8.2

# %% [markdown]
# ### Q1.
#
# Escreva uma função ```calcula_area_perimetro``` que recebe **apenas um parâmetro** ```dimensoes``` e calcula a área e o perímetro a partir das dimensões dadas.
# - ```dimensoes``` é uma tupla (largura, comprimento) com as dimensões de um terreno retangular
# - Sua função deve calcular e retornar as seguintes operações
#    - $area = largura \times comprimento$
#    - $perimetro = 2\times(largura + comprimento)$

# %%
# Implemente aqui a função calcula_area_perimetro
def calcula_area_perimetro(dimensoes):
  # Desempacotamento da tupla
  largura, comprimento = dimensoes
  
  # Cálculos
  area = largura * comprimento
  perimetro = 2 * (largura + comprimento)
  
  # Retornar os dois valores (como uma nova tupla)
  return (area, perimetro)

# %%
# Complete o exemplo de uso abaixo
largura = 5
comprimento = 7

retorno = calcula_area_perimetro((largura, comprimento)) ## complete aqui a chamada da função
print(retorno, type(retorno))
# Out:
# (35, 24) <class 'tuple'>

# %% [markdown]
# ### Q2.
#
# Dada uma string, imprima todas as vogais que aparecem na string, bem como todos os índices onde elas ocorrem. Para isso, use a função ```enumerate```.

# %%
frase = "O rato roeu a roupa da Alice"

# Implemente aqui sua solução
# Definimos as vogais
VOGAIS = "aeiou"

print(f"Analisando a frase: '{frase}'\n")

# 1. O enumerate() nos dá (índice, caractere) para cada item
for indice, char in enumerate(frase):
    
    # Verifica se o caractere, convertido para minúsculo,
    if char.lower() in VOGAIS:
        
        # Se for uma vogal, imprimimos o índice e a vogal original
        print(f"Índice: {indice}, Vogal: '{char}'")
# Out:
# Analisando a frase: 'O rato roeu a roupa da Alice'
#
# Índice: 0, Vogal: 'O'
# Índice: 3, Vogal: 'a'
# Índice: 5, Vogal: 'o'
# Índice: 8, Vogal: 'o'
# Índice: 9, Vogal: 'e'
# Índice: 10, Vogal: 'u'
# Índice: 12, Vogal: 'a'
# Índice: 15, Vogal: 'o'
# Índice: 16, Vogal: 'u'
# Índice: 18, Vogal: 'a'
# Índice: 21, Vogal: 'a'
# Índice: 23, Vogal: 'A'
# Índice: 25, Vogal: 'i'
# Índice: 27, Vogal: 'e'

# %% [markdown]
# ### Q3.
#
# Escreva uma função em Python chamada ```ordenar_tuplas``` que recebe uma lista de tuplas, cada uma contendo o nome de um aluno e sua respectiva média, e retorna uma nova lista ordenada em ordem decrescente de médias.

# %%
# Implemente aqui a função ordenar_tuplas
def ordenar_tuplas(lista_alunos_notas):
  
  return sorted(lista_alunos_notas, key=lambda tupla: tupla[1], reverse=True)

# %%
# Exemplo de uso:
alunos_notas = [('Alice', 8.5), ('Bob', 7.2), ('Charlie', 9.0), ('David', 8.8)]
resultado = ordenar_tuplas(alunos_notas)
print(resultado)
# Saída esperada: [('Charlie', 9.0), ('David', 8.8), ('Alice', 8.5), ('Bob', 7.2)]
# Out:
# [('Charlie', 9.0), ('David', 8.8), ('Alice', 8.5), ('Bob', 7.2)]

# %% [markdown]
# ### Q4.
#
# Escreva uma função em Python chamada ```comprimir_tuplas``` que recebe uma lista de tuplas, cada uma contendo uma palavra e um número, e retorna uma nova lista de tuplas onde palavras idênticas são agrupadas e seus números são somados.

# %%
# Implemente aqui a função comprimir_tuplas
def comprimir_tuplas(tuplas_originais):

  somas = {} # Dicionário para acumular
  
  # Itera pela lista
  for palavra, numero in tuplas_originais:
    somas[palavra] = somas.get(palavra, 0) + numero
    
  return list(somas.items())

# %%
# Exemplo de uso:
tuplas_originais = [('maçã', 3), ('banana', 2), ('maçã', 5), ('laranja', 1), ('banana', 3)]
resultado = comprimir_tuplas(tuplas_originais)
print(resultado)
# Saída esperada: [('maçã', 8), ('banana', 5), ('laranja', 1)]
# Out:
# [('maçã', 8), ('banana', 5), ('laranja', 1)]

# %% [markdown]
# ### Q5.
#
# - Escreva um script que peça o nome e a idade de todos na fila de uma balada. Crie uma lista de tuplas com os pares ```(nome, idade)``` de cada um.
# - Em seguida crie e imprima duas tuplas apenas com os nomes, uma com os menores de idade que não poderão entrar, e uma com os maiores de idade (```idade >= 18```).

# %%
## Implemente aqui sua solução
def coletar_fila_balada():
  fila_completa = [] # Lista para (nome, idade)
  
  print("--- Controle de Fila da Balada ---")
  print("(Deixe o nome em branco e pressione Enter para parar)\n")

  while True:
    nome = input("Nome: ")
    
    # Condição de parada: nome vazio
    if not nome:
      break
    
    # Loop para garantir que a idade é um número válido
    while True:
      try:
        idade_str = input(f"Idade de {nome}: ")
        idade = int(idade_str)
        if idade > 0:
          break # Sai do loop da idade se for um número válido
        else:
          print("Por favor, digite uma idade positiva.")
      except ValueError:
        print("Erro: A idade deve ser um número. Tente novamente.")
        
    # Adiciona a tupla à lista principal
    fila_completa.append((nome, idade))

  maiores_lista = [nome for (nome, idade) in fila_completa if idade >= 18]
  menores_lista = [nome for (nome, idade) in fila_completa if idade < 18]

  
  maiores_tupla = tuple(maiores_lista)
  menores_tupla = tuple(menores_lista)

  print("\n--- Relatório Final ---")
  print(f"Lista completa de (Nome, Idade): {fila_completa}")
  print("-" * 30)
  print(f"PODEM ENTRAR (Maiores): {maiores_tupla}")
  print(f"NÃO PODEM ENTRAR (Menores): {menores_tupla}")

coletar_fila_balada()
# Out:
# --- Controle de Fila da Balada ---
# (Deixe o nome em branco e pressione Enter para parar)
# Nome:  leozin
# Idade de leozin:  18
# Nome:  lionel
# Idade de lionel:  12
# Nome:
# --- Relatório Final ---
# Lista completa de (Nome, Idade): [('leozin', 18), ('lionel', 12)]
# ------------------------------
# PODEM ENTRAR (Maiores): ('leozin',)
# NÃO PODEM ENTRAR (Menores): ('lionel',)
